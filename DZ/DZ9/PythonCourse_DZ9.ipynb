# %% [markdown]
# Работать с файлом california_housing_train.csv, который находится в папке
# sample_data. Определить среднюю стоимость дома, где кол-во людей от 0 до 500 (population)

# %%
import pandas as pd
df=pd.read_csv('/content/sample_data/california_housing_train.csv')

# %%
df
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -114.31     34.19                15.0       5612.0          1283.0
# 1        -114.47     34.40                19.0       7650.0          1901.0
# 2        -114.56     33.69                17.0        720.0           174.0
# 3        -114.57     33.64                14.0       1501.0           337.0
# 4        -114.57     33.57                20.0       1454.0           326.0
# ...          ...       ...                 ...          ...             ...
# 16995    -124.26     40.58                52.0       2217.0           394.0
# 16996    -124.27     40.69                36.0       2349.0           528.0
# 16997    -124.30     41.84                17.0       2677.0           531.0
# 16998    -124.30     41.80                19.0       2672.0           552.0
# 16999    -124.35     40.54                52.0       1820.0           300.0
#
# ...

# %%
df[df['population']< 500] ['median_house_value'].mean()
# Out:
# 206683.83635227982

# %% [markdown]
# Для проверки. Смотрю мин и макс у population, но и среднее при этих условиях в колонке median_house_value

# %%
df[df['population']< 500].describe()
# Out:
#          longitude    latitude  housing_median_age  total_rooms  \
# count  1601.000000  1601.00000         1601.000000  1601.000000
# mean   -119.951961    36.25128           30.716427   743.332917
# std       2.060943     2.24854           13.688391   576.395186
# min    -124.250000    32.57000            1.000000     2.000000
# 25%    -121.950000    34.03000           19.000000   380.000000
# 50%    -120.160000    37.08000           32.000000   695.000000
# 75%    -118.180000    37.95000           42.000000   977.000000
# max    -114.560000    41.82000           52.000000  7744.000000
#
#        total_bedrooms   population   households  median_income  \
# count     1601.000000  1601.000000  1601.000000    1601.000000
# mean       152.392879   307.905684   121.876327       3.874544
# std        115.948744   138.231103    64.778524       2.371847
# min          1.000000     3.000000     1.000000       0.499900
# 25%         83.000000   202.000000    72.000000       2.300000
# ...

# %% [markdown]
# Узнать какая максимальная households в зоне минимального значения population

# %%
df[df['population'] == df['population'].min()]['households'].max()
# Out:
# 4.0
